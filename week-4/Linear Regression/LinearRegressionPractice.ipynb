# %%
# prompt: mount drive

from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv('/content/drive/MyDrive/ML/train.csv')

# %% [markdown]
# # function path

# %%
function readpath('/content/drive/MyDrive/ML/train.csv',pd.read_csv(path))
{
    return
}
train=readpath()

# %%
train.head(5)

# %%
train.info()

# %%
train.shape

# %%
train.duplicated()

# %%
train.drop_duplicates()

# %%
train.replace('?', np.nan)

# %%
train.isnull().sum()

# %%
train[''] = pd.to_numeric(train['Fare'], errors='coerce')

# %%
#imputation
train['price'].mean()
train['price'].fillna(train['price'].mean())

# %%
train.isnull().sum()

# %%
train_cleaned=train.drop('Cabin', axis=1)

# %%
train.shape

# %%
train_cleaned.shape

# %%
titanic_cleaned=train_cleaned.dropna()

# %%
titanic_cleaned.isnull().sum()

# %%
sns.boxplot(x='Sex', y='Age',data=titanic_cleaned)

# %%
sns.distplot(titanic_cleaned['Age'])

# %%
titanic_cleaned= titanic_cleaned[titanic_cleaned['Age']<68]

# %%
sns.boxplot(y='Age',data=titanic_cleaned)

# %% [markdown]
# # Linear Regression Practice

# %%
train.columns

# %%
X=train.drop(columns='Survived',inplace=False)
y=train['Survived']

# %%
X.head()

# %%
y.head()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train

# %%
y_train
